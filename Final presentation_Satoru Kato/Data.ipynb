# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('Data.csv')
X=dataset[["Sleep_Hours","Hours_Studied","Attendance","Motivation_Level"]]
Y=dataset["Exam_Score"]
X.head()
# Out:
#    Sleep_Hours  Hours_Studied  Attendance Motivation_Level
# 0            7             23          84              Low
# 1            8             19          64              Low
# 2            7             24          98           Medium
# 3            8             29          89           Medium
# 4            6             19          92           Medium

# %%
Y.head()
# Out:
# 0    67
# 1    61
# 2    74
# 3    71
# 4    70
# Name: Exam_Score, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

df=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred})
print(df)
# Out:
#       Actual  Predicted
# 2010      61  61.911078
# 653       62  63.268144
# 3487      67  67.803631
# 2865      69  70.214160
# 6181      68  70.168377
# ...      ...        ...
# 4853      70  69.117362
# 5701      63  66.119626
# 79        60  60.100483
# 5328      67  66.692846
# 4401      64  66.463781
#
# [1322 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
rmse=mean_squared_error(Y_test,y_pred)
mae=mean_absolute_error(Y_test,y_pred)
r2_score=r2_score(Y_test,y_pred)


print("MSE:",mse)
print("RMSE:",rmse)
print("MAE:",mae)
print("R2_Score:",r2_score)
#
# Out:
# MSE: 7.632693845790595
# RMSE: 7.632693845790595
# MAE: 1.5545369741887785
# R2_Score: 0.5449709059105764

# %%
new_data=[[6,15,40]]
ate=regressor.predict(new_data)
print(ate)
# Out:
# [58.07035682]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("coefficients",regressor.coef_)
print("intercept",regressor.intercept_)
# Out:
# coefficients [-0.0228916   0.28883607  0.19404143]
# intercept 46.1135080679108

# %%
new_data=[[16634.2,136787.8,461724.1]]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('Data.csv')
X=dataset[["Sleep_Hours","Attendance"]]
Y=dataset["Exam_Score"]
X.head()
# Out:
#    Sleep_Hours  Attendance
# 0            7          84
# 1            8          64
# 2            7          98
# 3            8          89
# 4            6          92

# %%
Y.head()
# Out:
# 0    67
# 1    61
# 2    74
# 3    71
# 4    70
# Name: Exam_Score, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

df=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred})
print(df)
# Out:
#       Actual  Predicted
# 3634      66  66.800641
# 902       66  67.584351
# 4287      70  69.364673
# 5958      66  64.632237
# 178       67  66.785553
# ...      ...        ...
# 5305      65  63.848527
# 1172      74  68.778777
# 2216      70  68.375605
# 2249      67  65.408402
# 4207      61  66.793097
#
# [1983 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
rmse=mean_squared_error(Y_test,y_pred)
mae=mean_absolute_error(Y_test,y_pred)
r2_score=r2_score(Y_test,y_pred)


print("MSE:",mse)
print("RMSE:",rmse)
print("MAE:",mae)
print("R2_Score:",r2_score)
#
# Out:
# MSE: 12.690806275995506
# RMSE: 12.690806275995506
# MAE: 2.228490791086101
# R2_Score: 0.27114806111353984

# %%
new_data=[[7,15]]
ate=regressor.predict(new_data)
print(ate)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1144037598.py in <cell line: 0>()
#       1 new_data=[[7,15]]
# ----> 2 ate=regressor.predict(new_data)
#       3 print(ate)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     295             Returns predicted values.
#     296         """
# --> 297         return self._decision_function(X)
#     298
#     299     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     274         check_is_fitted(self)
#     275
# ...

# %%
print("coefficients",regressor.coef_)
print("intercept",regressor.intercept_)
# Out:
# coefficients [0.29237446 0.19570094]
# intercept 45.758919341653105

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


import pandas as pd
import numpy as np

dataset = pd.read_csv("Data.csv")

col = "Attendance"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Atten_Stan"] = (x - x_min) / den

col = "Sleep_Hours"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Sleep_Hours_Stan"] = (x - x_min) / den

col = "Hours_Studied"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Hours_Studied_Stan"] = (x - x_min) / den

X=dataset[["Hours_Studied_Stan","Sleep_Hours_Stan","Atten_Stan"]]
Y=dataset["Exam_Score"]
X.head()
# Out:
#    Hours_Studied_Stan  Sleep_Hours_Stan  Atten_Stan
# 0            0.511628          0.500000       0.600
# 1            0.418605          0.666667       0.100
# 2            0.534884          0.500000       0.950
# 3            0.651163          0.666667       0.725
# 4            0.418605          0.333333       0.800

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
y_pred=regressor.predict(X_test)

df=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred})
print(df)
# Out:
#       Actual  Predicted
# 743       65  66.034610
# 5551      65  65.570786
# 3442      71  70.350032
# 6571      64  66.598932
# 4204      66  64.163371
# ...      ...        ...
# 4709      69  66.758773
# 3664      72  71.320712
# 5231      66  67.152072
# 1773      63  66.323583
# 5782      72  69.661365
#
# [1322 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(Y_test,y_pred)
rmse=np.sqrt(mse)
mae=mean_absolute_error(Y_test,y_pred)
r2_score=r2_score(Y_test,y_pred)


print("MSE:",mse)
print("RMSE:",rmse)
print("MAE:",mae)
print("R2_Score:",r2_score)
#
# Out:
# MSE: 5.666549310467277
# RMSE: 2.3804514929876803
# MAE: 1.4362681920856046
# R2_Score: 0.5991142372089825

# %%
new_data=[[0.1,0.8,0.1,0.9]]
ate=regressor.predict(new_data)
print(ate)
# Out:
# [60.57656903]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
dataset = pd.read_csv("Data.csv")

col = "Attendance"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Atten_Stan"] = (x - x_min) / den

col = "Sleep_Hours"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Sleep_Hours_Stan"] = (x - x_min) / den

col = "Hours_Studied"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Hours_Studied_Stan"] = (x - x_min) / den

X=dataset[["Hours_Studied_Stan","Sleep_Hours","Atten_Stan"]]
Y=dataset["Exam_Score"]

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
alphas = np.logspace(-4, 4, 30)  # 1e-4〜1e4 を広めに探索

model = Pipeline([
    ("scaler", StandardScaler()),
    ("ridge", RidgeCV(alphas=alphas, cv=5))
])

model.fit(X_train, Y_train)

best_alpha = model.named_steps["ridge"].alpha_
print("best alpha:", best_alpha)
# Out:
# best alpha: 0.0001

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
# Create a Ridge regression model
ridge = Ridge(alpha=0.0001) # You can adjust the alpha parameter
# Fit the model to the training data
ridge.fit(X_train, Y_train)
# Predict on the test data
y_pred_ridge = ridge.predict(X_test)

# %%
df=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred_ridge})
print(df)
# Out:
#       Actual  Predicted
# 743       65  66.034610
# 5551      65  65.570785
# 3442      71  70.350032
# 6571      64  66.598934
# 4204      66  64.163372
# ...      ...        ...
# 4709      69  66.758773
# 3664      72  71.320709
# 5231      66  67.152071
# 1773      63  66.323583
# 5782      72  69.661364
#
# [1322 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(Y_test,y_pred_ridge)
rmse=np.sqrt(mse)
mae=mean_absolute_error(Y_test,y_pred_ridge)
r2_score=r2_score(Y_test,y_pred_ridge)


print("MSE:",mse)
print("RMSE:",rmse)
print("MAE:",mae)
print("R2_Score:",r2_score)
#
# Out:
# MSE: 5.66654960462754
# RMSE: 2.380451554774333
# MAE: 1.436268261878059
# R2_Score: 0.5991142163983172

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
dataset = pd.read_csv("Data.csv")

col = "Attendance"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Atten_Stan"] = (x - x_min) / den

col = "Sleep_Hours"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Sleep_Hours_Stan"] = (x - x_min) / den

col = "Hours_Studied"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Hours_Studied_Stan"] = (x - x_min) / den

mapping = {"Low": 1, "Medium": 2, "High": 3}
dataset["Level_num"] = dataset["Motivation_Level"].map(mapping)

col = "Level_num"
x = dataset[col].to_numpy(dtype=float)
x_min = np.nanmin(x)
x_max = np.nanmax(x)
den = x_max - x_min
dataset["Level_Stan"] = (x - x_min) / den

X=dataset[["Hours_Studied_Stan","Sleep_Hours","Atten_Stan","Level_Stan"]]
Y=dataset["Exam_Score"]
X.head()
# Out:
#    Hours_Studied_Stan  Sleep_Hours  Atten_Stan  Level_Stan
# 0            0.511628            7       0.600         0.0
# 1            0.418605            8       0.100         0.0
# 2            0.534884            7       0.950         0.5
# 3            0.651163            8       0.725         0.5
# 4            0.418605            6       0.800         0.5

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=42)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoCV

model = Pipeline([
    ("scaler", StandardScaler()),
    ("lasso", LassoCV(
        alphas=None,
        cv=5,
        random_state=42,
        max_iter=100000
    ))
])

model.fit(X_train, Y_train)

best_alpha = model.named_steps["lasso"].alpha_
print("best alpha:", best_alpha)
# Out:
# best alpha: 0.0022707555493139383

# %%
# Create a Lasso regression model
lasso = Lasso(alpha=0.0022707555493139383) # You can adjust the alpha parameter
# Fit the model to the training data
lasso.fit(X_train, Y_train)
# Predict on the test data
y_pred_lasso = lasso.predict(X_test)

# %%
df=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred_lasso})
print(df)
# Out:
#       Actual  Predicted
# 743       65  65.822714
# 5551      65  65.993988
# 3442      71  69.348310
# 6571      64  67.662550
# 4204      66  64.565641
# ...      ...        ...
# 4709      69  66.914401
# 3664      72  70.110214
# 5231      66  66.497016
# 1773      63  66.664360
# 5782      72  68.931413
#
# [1322 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(Y_test,y_pred_lasso)
rmse=np.sqrt(mse)
mae=mean_absolute_error(Y_test,y_pred_lasso)
r2_score=r2_score(Y_test,y_pred_lasso)


print("MSE:",mse)
print("RMSE:",rmse)
print("MAE:",mae)
print("R2_Score:",r2_score)
#
# Out:
# MSE: 6.5307296316495815
# RMSE: 2.555529227312727
# MAE: 1.6375892568831558
# R2_Score: 0.5379769262521691

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import HuberRegressor

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create a Huber regression model (robust regression)
huber = HuberRegressor(epsilon=5.5, alpha=0.0001, max_iter=100)
#1.2, 1.35, 1.5, 1.8, 2.0(epsilon)
#0（正則化なし）〜 1e-2 くらい(alpha)

# Fit the model to the training data
huber.fit(X_train, Y_train)

# Predict on the test data
y_pred_huber = huber.predict(X_test)

# %%
df=pd.DataFrame({'Actual':Y_test,'Predicted':y_pred_huber})
print(df)
# Out:
#       Actual  Predicted
# 743       65  65.934900
# 5551      65  65.484915
# 3442      71  70.235314
# 6571      64  66.497691
# 4204      66  64.089624
# ...      ...        ...
# 4709      69  66.720802
# 3664      72  71.250006
# 5231      66  67.043699
# 1773      63  66.214996
# 5782      72  69.537596
#
# [1322 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error,mean_absolute_error,r2_score
mse=mean_squared_error(Y_test,y_pred_huber)
rmse=np.sqrt(mse)
mae=mean_absolute_error(Y_test,y_pred_huber)
r2_score=r2_score(Y_test,y_pred_huber)


print("MSE:",mse)
print("RMSE:",rmse)
print("MAE:",mae)
print("R2_Score:",r2_score)
#
# Out:
# MSE: 5.661273900049828
# RMSE: 2.3793431656761554
# MAE: 1.430785649455135
# R2_Score: 0.5994874514551425

# %%
import pandas as pd

df = pd.read_csv("Data.csv")

mapping = {"Low": 1, "Medium": 2, "High": 3}
df["Level_num"] = df["Motivation_Level"].map(mapping)   # 新しい列にしたい場合

# 置き換えて元列を上書きするなら
# df["Level"] = df["Level"].map(mapping)
X=df["Level_num"]
X.head()
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    2
# Name: Level_num, dtype: int64
